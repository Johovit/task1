# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:

    page=requests.get('https://www.cricbuzz.com/')

except Exception as e:
    error_type, error_obj, error_info = sys.exc_info()
    print ('ERROR FOR LINK:',url)
    print (error_type, 'Line:', error_info.tb_lineno)

time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta charset="utf-8"/><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>html{scroll-behavior: smooth;}	body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-65 {width:65%;}	.cb-col-66 {width:66%;}	.cb-col-67 {width:67%;}	.cb-col-73 {width:73%;}	.cb-col-75 {width:75%;}	.cb-col-70 {width:70%;}	.cb-col-84 {width:84%;}	.cb-col-80 {width:80%;}	.cb-col-90{width:90%;}	.cb-col-100 {width:100%;}	.cb-col {display: inline-block;box-sizing: border-box;float: left; min-height: 1px;}	h1 {font-size: 36px;line-height: 42px; margin:0;}	h2 {font-size: 24px; margin:0; line-height: 30px;}	h3 {font-size: 18px;line-height: 24px; margin:0; }	h4 {font-size: 16px; margin:0; }	h5 {font-size: 14px; margin: 0;}	.cb-font-18 {font-size:18px;}	img{border-radius: 4px;}	a {text-decoration: none; color:#222;}	a, a:hover, a:active, a:focus {outline: medium none;}	.text-center {text-align: center;}	.cb-nws-lft-col{padding:15px 20px;}	.cb-nws-dtl-lft-col {padding: 10px 30px 0 30px;border-right: 1px solid #ecebeb ;}	.cb-nws-lst-rt{padding-left: 10px;}	.cb-srs-lst-itm {padding: 10px 0;}	.cb-lst-itm-sm{padding:10px 0 5px;}	.cb-scrd-lft-col{padding:15px 10px;} .cb-col-rt{padding: 10px;}	.text-white{color: #fff;}	.cb-text-apple-red{color: #E90B37;}	.cb-color-light-sec{color: #464646;}	.cb-scrd-hdr-rw, .cb-nav-pill-1.active {background: #028062 ;color: #fff;}	.cb-nav{position:relative; height:48px;background: #009270;}	.cb-hm-mnu-itm{padding: 16px 6px 11px; color:#fff; display:inline-block;}	.cb-hm-text{padding:10px 18px 10px 20px;}	.cb-hm-rght{padding: 15px;}	.cb-subnav .cb-sub-navigation {display: none; position: absolute;}	.cb-mat-mnu{background:#4a4a4a; width:980px; font-size: 0;}	.cb-mat-mnu-itm{font-size:12px; color:#fff; padding:10px; cursor: pointer; display:inline-block; max-width: 140px;}	.cb-mat-mnu-ttl{background: #333; padding: 10px 20px;}	.cb-mat-mnu-wrp{margin-bottom: 10px;}	.cb-ovr-flo{overflow: hidden; white-space: nowrap; text-overflow: ellipsis;}	.cb-mat-mnu-all{text-align: center; float: right; width:60px;}	.cb-nav-main{border-bottom:1px solid #e3e6e3;padding:0 0 5px 20px;}	.cb-nav-bar{padding-top:10px;clear:both;}	.cb-lst-itm, .cb-bg-white{background: #fff;}	.cb-nav-tab.active, .cb-nav-tab-hm.active{ font-weight: bold; color: #028062;}	.cb-nav-tab.active {border-bottom: 3px solid #028062; line-height: 24px; }	.cb-nav-tab-hm.active{ border-bottom:2px solid #028062; line-height: 22px;}	.cb-nav-tab{margin-right:20px;padding-bottom:6px;}	.cb-nav-tab-hm{margin-right:15px;padding-bottom:6px;}	.cb-nav-hdr{padding-top:15px}	.cb-nav-subhdr{padding:5px 0 10px 0;}	.cb-lv-scr-mtch-hdr{line-height: 21px;font-size: 16px;}	.disp-none{display:none;}	.disp-blck{display:block;}	.cb-font-24{font-size: 24px;}	.line-ht30{line-height: 30px;}	.line-ht24{line-height: 24px;}	.cb-hm-scg-blk{background: #fff; margin-bottom: 5px; height:90px;}	.mrgn-btm-5{margin-bottom : 5px;}	#scagTabContent .show{display: block; visibility: visible;}	#scagTabContent .hide{display: none; visibility: hidden;}	[ng\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak { display: none !important;}	.cb-hm-lft{margin-bottom:5px;padding:0 15px;}	.cb-hm-lft-hd ...
# .cb-plus-menu-button{padding: 8px 10px; background: #fff; border-radius: 18px; border: 0;width: 104px;height:14px;display: inline-block; text-align: center; line-height:1; }
# .cb-plus-menu-button:hover,.cb-plus-menu-button:focus, .cb-plus-menu-button:active{background: #fff;}
# .cb-imp-abs{position: absolute !important;}</style></div></header><div class="page"><div id="fb-root"></div><div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/118916/mi-vs-gt-eliminator-indian-premier-league-2025" target="_self" title="Mumbai Indians v Gujarat Titans, Eliminator - Live">MI vs GT - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/118907/pbks-vs-rcb-qualifier-1-indian-premier-league-2025" target="_self" title="Punjab Kings v Royal Challengers Bengaluru, Qualifier 1 - RCB Won">PBKS vs RCB - RCB Won</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/119009/inda-vs-enga-1st-unofficial-test-india-a-tour-of-england-2025" target="_self" title="India A v England Lions, 1st Unofficial Test - Live">INDA vs ENGA - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/105876/engw-vs-wiw-1st-odi-west-indies-women-tour-of-england-2025" target="_self" title="England Women v West Indies Women, 1st ODI - Live">ENGW vs WIW - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/105818/eng-vs-wi-1st-odi-west-indies-tour-of-england-2025" target="_self" title="England v West Indies, 1st ODI - ENG Won">ENG vs WI - ENG Won</a><span ng-click="(direction=='up')?direction = 'down' : direction = 'up'"><a class="cb-mat-mnu-itm cb-mat-mnu-all" id="match-dropdown" ng-class="{true:'cb-mat-mnu-cls'}[direction=='down']"><span ng-bind="(direction=='up') ? 'ALL': 'CLOSE'"></span><span ng-class="(direction=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></span></nav><div id="matchmenu"><div class="cb-mm-wrp {{direction}}"><div class="cb-scg-drp-dwn cb-col cb-col-100 cb-mnu-{{direction}}"><nav class="nav cb-mm-nvtb" ng-init="option= 'all'"><a class="cb-nav-pill-2 {{(option=='all')?'active':''}}" ng-click="option='all'" style="margin-right: 20px;">All</a><a class="cb-nav-pill-2 {{(option=='live')?'active':''}}" ng-click="option='live'" style="margin-right: 20px;">Live Now</a><a class="cb-nav-pill-2 {{(option=='today')?'active':''}}" ng-click="option='today'" style="margin-right: 20px;">Today</a></nav><style>.cb-nt-{{option}}{opacity:0.4!important;}</style><ul class="cb-scg-drp-dwn-ul"><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">INTERNATIONAL</div><div class="cb-scg-srs-nm">West Indies tour of England</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/105818/eng-vs-wi-1st-odi-west-indies-tour-of-england" target="_self" title="England v West Indies, 1st ODI - ENG Won"><span class="cb-mm-mtch-tm">England vs West Indies</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">1st ODI</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/105820/eng-vs-wi-2nd-odi-west-indies-tour-of-england" target="_self" title="England v West Indies, 2nd ODI - Upcoming"><span class="cb-mm-mtch-tm">England vs West Indies</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">2nd ODI</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-scg-srs-nm">Pakistan v Bangladesh</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/119447/pak-vs-ban-1st ...
# }</style> <meta content="400" http-equiv="refresh"/> <div class="cb-bg-white cb-col cb-col-100 disp-flex align-center cb-qck-lnk" ng-controller="CBPlusAuth" ng-init="initiate_cb_editorial_carousal();"> <h1 class="cb-qck-acs-hdr cb-sign-up-google min-width-fit-con">Quick Access</h1> <nav class="" style="white-space: nowrap; overflow: hidden; height: 35px;"> <div class="cb-editorial-carousal-wrapper disp-flex align-center" style="height: 35px;"> <a class="cb-bg-off-white min-width-fit-con" href="/cricket-series/9237/Indian-Premier-League-2025" style="margin-left: 10px; padding: 8px 10px 8px 10px; border-radius: 2px;" title="IPL 2025"> <span class="cb-plus-ico cb-trophy-icon scale-080 cb-padd-rt-5"></span> <span class="cb-font-w-500">IPL 2025</span> </a> <a class="cb-bg-off-white min-width-fit-con" href="/cb-plus/premium-content/home" style="margin-left: 10px; padding: 8px 10px 8px 10px; border-radius: 2px;" title="Willow by Cricbuzz"> <span class="cb-plus-ico cb-plus-sign-icon scale-080 cb-padd-rt-5"></span> <span class="cb-font-w-500">Willow by Cricbuzz</span> </a> <a class="cb-bg-off-white min-width-fit-con" href="/premium-subscription/user/select-plan/cricbuzz-promo" ng-if="!(user_state === 'ACTIVE' || user_state === 'ACTIVE_CANCELLED')" style="margin-left: 10px; padding: 8px 10px 8px 10px; border-radius: 2px;" title="See Plans"> <span class="cb-plus-ico cb-subs-quick-access-icon scale-080 cb-padd-rt-5"></span> <span class="cb-font-w-500">See Plans</span> </a> <a class="cb-bg-off-white min-width-fit-con" href="/cricket-team/India/2" style="margin-left: 10px; padding: 8px 10px 8px 10px; border-radius: 2px;" title="Team India"> <span class="cb-plus-ico cb-teams-icon scale-080 cb-padd-rt-5"></span> <span class="cb-font-w-500">Team India</span> </a> </div> </nav> </div> <div class="cb-col cb-col-20"> <div class="cb-bg-white" id="cb-news-blck"><h2 class="cb-hm-lft-hdr cb-lv-scr-mtch-hdr">LATEST NEWS</h2><div class="cb-hm-lft"><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/134498/icc-to-implement-new-playing-conditions-from-next-month" title="ICC to implement new playing conditions from next month">ICC to implement new playing conditions from next month</a><div class="cb-nws-time">2h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/134497/aminul-islam-takes-over-as-bcb-president-bangladesh-cricket" title="Aminul Islam takes over as new BCB president">Aminul Islam takes over as new BCB president</a><div class="cb-nws-time">6h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/134494/my-primary-goal-is-to-hold-a-transparent-election-at-bangladesh-cricket-board-says-former-bangladesh-cricket-team-captain-aminul-islam-bcb-news" title="Primary goal is to hold transparent elections at BCB - Aminul Islam">Primary goal is to hold transparent elections at BCB - Aminul Islam</a><div class="cb-nws-time">14h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/134493/ipl-2025-qualifier-1-punjab-kings-vs-rcb-worst-thing-pbks-batters-can-do-now-is-blink-and-jump-at-shadows-says-bowling-coach-james-hopes" title="'Worst thing PBKS batters can do now is blink and jump at shadows'">'Worst thing PBKS batters can do now is blink and jump at shadows'</a><div class="cb-nws-time">15h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/134492/faruque-ahmed-removed-as-bcb-president-following-nsc-pullout" title="Faruque Ahmed removed as BCB president following NSC pullout">Faruque Ahmed removed as BCB president following NSC pullout</a><div class="cb-nws-time">22h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" hre ...
# });</script> <div class="cb-col cb-hm-mid cb-bg-white cb-hmpage" style="clear:both"> <div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>IPL 2025</span></div><a href="/cricket-news/134495/rcb-bury-pbks-beneath-a-wave-of-intensity" title="RCB bury PBKS beneath a wave of intensity"><img alt="RCB bury PBKS beneath a wave of intensity" height="235" itemprop="image" src="https://static.cricbuzz.com/a/img/v1/420x235/i1/c710267/rcb-bury-pbks-beneath-a-wave-o.jpg" title="RCB bury PBKS beneath a wave of intensity" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/134495/rcb-bury-pbks-beneath-a-wave-of-intensity" title="RCB bury PBKS beneath a wave of intensity">	RCB bury PBKS beneath a wave of intensity</a></h2><div class="cb-nws-intr">The perennial title-chasers snuffed out PBKS' batting swagger with relentless precision, inching ever closer to their moment of reckoning</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/134491/salt-caps-bowlers-onslaught-as-rcb-blaze-a-trail-to-ipl-2025-final" title="Salt caps bowlers' onslaught as RCB blaze a trail to IPL 2025 final">Salt caps bowlers' onslaught as RCB blaze a trail to IPL 2025 final</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/134493/worst-thing-pbks-batters-can-do-now-is-blink-and-jump-at-shadows" title="'Worst thing PBKS batters can do now is blink and jump at shadows'">'Worst thing PBKS batters can do now is blink and jump at shadows'</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/134438/rcb-one-step-away-from-ipl-title" title="RCB, one step away from IPL title"><span class="cb-pretag">Pulse / </span>RCB, one step away from IPL title</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>RULES TWEAKED</span></div><a href="/cricket-news/134498/icc-to-implement-new-playing-conditions-from-next-month" title="ICC to implement new playing conditions from next month"><img alt="ICC to implement new playing conditions from next month" height="235" itemprop="image" src="https://static.cricbuzz.com/a/img/v1/420x235/i1/c710331/icc-to-implement-new-playing-c.jpg" title="ICC to implement new playing conditions from next month" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/134498/icc-to-implement-new-playing-conditions-from-next-month" title="ICC to implement new playing conditions from next month">	ICC to implement new playing conditions from next month</a></h2><div class="cb-nws-intr">The rules will be in force from the first Test between Sri Lanka and Bangladesh scheduled for next month</div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>BANGLADESH CRICKET</span></div><a href="/cricket-news/134497/aminul-islam-takes-over-as-new-bcb-president" title="Aminul Islam takes over as new BCB president"><img alt="Aminul Islam takes over as new BCB president" height="235" itemprop="image" src="https://static.cricbuzz.com/a/img/v1/420x235/i1/c710284/aminul-islam-takes-over-as-new.jpg" title="Aminul Islam takes over as new BCB president" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/134497/aminul-islam-takes-over-as-new-bcb-president" title="Aminul Islam takes over as new BCB president">	Aminul Islam takes over as new BCB president</a></h2><div class="cb-nws-intr">The former national skipper becomes the 16th president of the Bangladesh board</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/134492/faruque-ahmed-removed-as-bcb-president-following-nsc-pullout" title="Faruque Ahmed removed as BCB president following NSC pullout">Faruque Ahmed removed as BCB president following NSC pullout</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/134494/primary-goal-is-to-hold-transparent-elections-at-bcb-aminul-islam" title="Primary goal is to hold transparent elections at BCB ...

# %%
links
# Out:
# [<div class="cb-nws-intr">The perennial title-chasers snuffed out PBKS' batting swagger with relentless precision, inching ever closer to their moment of reckoning</div>,
#  <div class="cb-nws-intr">The rules will be in force from the first Test between Sri Lanka and Bangladesh scheduled for next month</div>,
#  <div class="cb-nws-intr">The former national skipper becomes the 16th president of the Bangladesh board</div>,
#  <div class="cb-nws-intr">It is understood that now-retired Rohit Sharma convinced Gautam Gambhir and the BCCI to retain T Dilip, who had been let go following India's performances against New Zealand and Australia</div>,
#  <div class="cb-nws-intr">Come the WTC final, footy and rugby will make room for cricket in Australia and South Africa, if only for a week </div>,
#  <div class="cb-nws-intr">Ben Duckett, Joe Root, Harry Brook and Jacob Bethell slammed breezy half-centuries as the hosts put up a massive total of 400 batting first</div>,
#  <div class="cb-nws-intr">The 43-year old, who led CSK to victory in their last outing in IPL 2025, did not give a definitive answer to a question about what the future holds for him as a player</div>,
#  <div class="cb-nws-intr">The 35-year-old has hit the most number of first-class centuries by a Gujarat player</div>,
#  <div class="cb-nws-intr">Ganguly and his wife had to be rescued by local divers and life-savers after their boat capsized on Saturday</div>,
#  <div class="cb-nws-intr">News bytes that you may have missed otherwise</div>,
#  <div class="cb-nws-intr">In a format where every ball counts, the subtle art of sequencing deliveries can make all the difference. We look at how the order and timing of variations is shaping modern bowling strategies</div>,
#  <div class="cb-nws-intr">Kohl stripped Test cricket of its ornamental restraint and dressed it in muscle and intent. He walked into hostile grounds with his collar turned up, demanded fast bowlers give "hell to opposition" and treated draws as a last resort</div>,
#  <div class="cb-nws-intr">The anatomy of a rivalry that shouldn't exist, but does.</div>,
#  <div class="cb-nws-intr">In a chat with Cricbuzz, DC's 20-year-old all-rounder talks about his journey into the bright lights of the IPL</div>,
#  <div class="cb-nws-intr">LSG have turned their premium retention at 21 crore into a shrewd call by making him the unconditional No.3</div>,
#  <div class="cb-nws-intr">Sunrisers Hyderabad's latest batting discovery is getting used to turning heads in the moments when it counts</div>,
#  <div class="cb-nws-intr">From nearly quitting cricket in 2018, Arora talks exclusively about how he came to be a key member of KKR's bowling attack</div>,
#  <div class="cb-nws-intr">As data and dugouts take over, what does it even mean to be a T20 captain any more?</div>,
#  <div class="cb-nws-intr">With Maxwell, the magic seems to happen when attention drifts. It's a lesson his PBKS head coach, Ricky Ponting, and every fan must learn painfully, and often</div>,
#  <div class="cb-nws-intr">News bytes that you may have missed otherwise</div>,
#  <div class="cb-nws-intr">While all signs suggest that the Impact Player rule has empowered batters, this analysis delves into the finer details</div>,
#  <div class="cb-nws-intr">Mining the data shows us which characteristics help batters stand out from the crowd, and what skills might set them apart in the future</div>,
#  <div class="cb-nws-intr">Do we have the mental and digital bandwidth to track all the cricket that's on?</div>,
#  <div class="cb-nws-intr">Two trends in women's cricket show the value that T20 leagues bring to developing the game, and the inequality in that development</div>,
#  <div class="cb-nws-intr">The great sell-off in The Hundred has changed English cricket forever, and there is no going back now</div>]

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# The perennial title-chasers snuffed out PBKS' batting swagger with relentless precision, inching ever closer to their moment of reckoning
#
#
# The rules will be in force from the first Test between Sri Lanka and Bangladesh scheduled for next month
#
#
# The former national skipper becomes the 16th president of the Bangladesh board
#
#
# It is understood that now-retired Rohit Sharma convinced Gautam Gambhir and the BCCI to retain T Dilip, who had been let go following India's performances against New Zealand and Australia
#
#
# Come the WTC final, footy and rugby will make room for cricket in Australia and South Africa, if only for a week
#
#
# Ben Duckett, Joe Root, Harry Brook and Jacob Bethell slammed breezy half-centuries as the hosts put up a massive total of 400 batting first
#
#
# The 43-year old, who led CSK to victory in their last outing in IPL 2025, did not give a definitive answer to a question about what the future holds for him as a player
#
#
# The 35-year-old has hit the most number of first-class centuries by a Gujarat player
#
#
# Ganguly and his wife had to be rescued by local divers and life-savers after their boat capsized on Saturday
#
#
# News bytes that you may have missed otherwise
#
#
# In a format where every ball counts, the subtle art of sequencing deliveries can make all the difference. We look at how the order and timing of variations is shaping modern bowling strategies
#
#
# Kohl stripped Test cricket of its ornamental restraint and dressed it in muscle and intent. He walked into hostile grounds with his collar turned up, demanded fast bowlers give "hell to opposition" and treated draws as a last resort
#
#
# The anatomy of a rivalry that shouldn't exist, but does.
#
#
# In a chat with Cricbuzz, DC's 20-year-old all-rounder talks about his journey into the bright lights of the IPL
#
#
# LSG have turned their premium retention at 21 crore into a shrewd call by making him the unconditional No.3
#
#
# Sunrisers Hyderabad's latest batting discovery is getting used to turning heads in the moments when it counts
#
#
# From nearly quitting cricket in 2018, Arora talks exclusively about how he came to be a key member of KKR's bowling attack
#
#
# As data and dugouts take over, what does it even mean to be a T20 captain any more?
#
#
# With Maxwell, the magic seems to happen when attention drifts. It's a lesson his PBKS head coach, Ricky Ponting, and every fan must learn painfully, and often
#
#
# News bytes that you may have missed otherwise
#
#
# While all signs suggest that the Impact Player rule has empowered batters, this analysis delves into the finer details
#
#
# Mining the data shows us which characteristics help batters stand out from the crowd, and what skills might set them apart in the future
#
#
# Do we have the mental and digital bandwidth to track all the cricket that's on?
#
#
# Two trends in women's cricket show the value that T20 leagues bring to developing the game, and the inequality in that development
#
#
# The great sell-off in The Hundred has changed English cricket forever, and there is no going back now
